# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
import json
import numpy as np

# %%
coords = '/Users/justinpak/Desktop/crowd_counter_project_lewagon/RGBT-CC-CVPR2021/test/1197_GT.json'

# %%
with open(coords,'r') as f:
    data = json.load(f)

# %%
coordinates = np.array(data['points'])

# %%
picture = imread('/Users/justinpak/Desktop/crowd_counter_project_lewagon/RGBT-CC-CVPR2021/test/1197_RGB.jpg')

# %%
plt.imshow(picture)

# %%
picture.shape
# Out:
# (480, 640, 3)

# %%
coordinates
# Out:
# array([[627.6744186 , 171.62790698],
#        [569.21214998, 218.94162316],
#        [561.2529663 , 200.57427622],
#        [586.35500712, 181.59468439],
#        [577.78357855, 157.71713336],
#        [530.02847651, 154.04366398],
#        [495.13051732, 155.88039867],
#        [497.57949692, 172.41101092],
#        [509.21214998, 202.41101092],
#        [492.06929283, 224.45182724],
#        [474.31419079, 199.96203132],
#        [462.06929283, 179.14570479],
#        [425.33459896, 140.57427622],
#        [425.94684385, 151.59468439],
#        [413.089701  , 155.26815377],
#        [435.13051732, 169.34978643],
#        [425.33459896, 188.32937826],
#        [410.6407214 , 202.41101092],
#        [383.089701  , 190.77835785],
#        [381.2529663 , 166.90080683],
#        [384.31419079, 148.5334599 ],
#        [355.53868059, 158.32937826],
#        [338.39582345, 124.04366398],
#        [332.88561936, 141.79876602],
#        [320.6407214 , 149.14570479],
#        [299.82439487, 210.98243949],
#        [290.02847651, 113.63550071],
#        [286.96725202, 133.22733745],
#        [285.74276222, 150.37019459],
#        [248.39582345, 180.98243949],
#        [361.66112957, 248.32937826],
#        [245.94684385, 127.10488847],
#        [225.74276222, 116.0844803 ],
#        [237.98766018, 112.41101092],
#        [171.8652112 , 180.37019459],
#        [194.51827243, 154.04366398],
#        [198.19174181, 117.3089701 ],
#        [183.49786426, 122.20692928],
#        [165.13051732, 120.98243949],
#        [154.11010916, 147.3089701 ],
#        [170.02847651, 153.43141908],
#        [132.68153773, 166.28856194],
#        [114.92643569, 113.02325581],
#        [106.35500712, 125.88039867],
#        [113.70194589, 135.06407214],
#        [122.88561936, 117.3089701 ],
#        [138.80398671, 122.81917418],
#        [152.88561936, 120.98243949],
#        [146.76317038, 118.5334599 ],
#        [129.62031324, 125.88039867],
#        [ 39.62031324, 144.85999051],
#        [ 32.88561936, 124.04366398],
#        [ 16.35500712, 123.43141908],
#        [ 67.25044469, 160.24788958],
#        [  8.39582345, 136.90080683],
#        [  2.88561936, 118.5334599 ],
#        [ 98.5839594 , 155.75311518],
#        [206.7190802 , 133.07143427]])

# %%
new_coords = [[y,x] for x,y in coordinates]

# %%
flipped_coordinates = np.array(new_coords).astype(int)

# %%
flipped_coordinates
# Out:
# array([[171, 627],
#        [218, 569],
#        [200, 561],
#        [181, 586],
#        [157, 577],
#        [154, 530],
#        [155, 495],
#        [172, 497],
#        [202, 509],
#        [224, 492],
#        [199, 474],
#        [179, 462],
#        [140, 425],
#        [151, 425],
#        [155, 413],
#        [169, 435],
#        [188, 425],
#        [202, 410],
#        [190, 383],
#        [166, 381],
#        [148, 384],
#        [158, 355],
#        [124, 338],
#        [141, 332],
#        [149, 320],
#        [210, 299],
#        [113, 290],
#        [133, 286],
#        [150, 285],
#        [180, 248],
#        [248, 361],
#        [127, 245],
#        [116, 225],
#        [112, 237],
#        [180, 171],
#        [154, 194],
#        [117, 198],
#        [122, 183],
#        [120, 165],
#        [147, 154],
#        [153, 170],
#        [166, 132],
#        [113, 114],
#        [125, 106],
#        [135, 113],
#        [117, 122],
#        [122, 138],
#        [120, 152],
#        [118, 146],
#        [125, 129],
#        [144,  39],
#        [124,  32],
#        [123,  16],
#        [160,  67],
#        [136,   8],
#        [118,   2],
#        [155,  98],
#        [133, 206]])

# %%
from PIL import Image

# %%
img = Image.new('RGB',(480,640),color='black')

for x,y in coordinates:
    img.putpixel((x,y),(255,0,0))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=480x640>

# %%
img_array = np.array(img)

# %%
img_array[172, 628, :]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [86], line 1
# ----> 1 img_array[172, 628, :]
#
# IndexError: index 628 is out of bounds for axis 1 with size 480
