# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
import json
import numpy as np

# %%
coords = '/Users/justinpak/Desktop/crowd_counter_project_lewagon/RGBT-CC-CVPR2021/test/1197_GT.json'

# %%
with open(coords,'r') as f:
    data = json.load(f)

# %%
coordinates = np.array(data['points'])

# %%
picture = imread('/Users/justinpak/Desktop/crowd_counter_project_lewagon/RGBT-CC-CVPR2021/test/1197_RGB.jpg')

# %%
plt.imshow(picture)
plt.scatter(x=coordinates[:,0],y=coordinates[:,1])

# %%
# Out:
# '/Users/justinpak/code/justinpakzad/head_hunter/annoated_images'

# %%
cd annoated_images/
# Out:
# /Users/justinpak/code/justinpakzad/head_hunter/annoated_images

# %%
picture.shape
# Out:
# (480, 640, 3)

# %%
coordinates = coordinates.astype(int)

# %%
new_coords = [[y,x] for x,y in coordinates]

# %%
flipped_coordinates = np.array(new_coords).astype(int)

# %%
flipped_coordinates
# Out:
# array([[171, 627],
#        [218, 569],
#        [200, 561],
#        [181, 586],
#        [157, 577],
#        [154, 530],
#        [155, 495],
#        [172, 497],
#        [202, 509],
#        [224, 492],
#        [199, 474],
#        [179, 462],
#        [140, 425],
#        [151, 425],
#        [155, 413],
#        [169, 435],
#        [188, 425],
#        [202, 410],
#        [190, 383],
#        [166, 381],
#        [148, 384],
#        [158, 355],
#        [124, 338],
#        [141, 332],
#        [149, 320],
#        [210, 299],
#        [113, 290],
#        [133, 286],
#        [150, 285],
#        [180, 248],
#        [248, 361],
#        [127, 245],
#        [116, 225],
#        [112, 237],
#        [180, 171],
#        [154, 194],
#        [117, 198],
#        [122, 183],
#        [120, 165],
#        [147, 154],
#        [153, 170],
#        [166, 132],
#        [113, 114],
#        [125, 106],
#        [135, 113],
#        [117, 122],
#        [122, 138],
# ...

# %%
from PIL import Image

# %%
img = Image.new('RGB',(640,480),color='black')

for x,y in coordinates:
    img.putpixel((x, y),(255,0,0))

# %%
plt.plot(img)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [116], line 1
# ----> 1 plt.plot(img)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/matplotlib/pyplot.py:2767, in plot(scalex, scaley, data, *args, **kwargs)
#    2765 @_copy_docstring_and_deprecators(Axes.plot)
#    2766 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2767     return gca().plot(
#    2768         *args, scalex=scalex, scaley=scaley,
#    2769         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1635, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1393 """
#    1394 Plot y versus x as lines and/or markers.
#    1395
#    (...)
#    1632 (``'green'``) or hex strings (``'#008000'``).
#    1633 """
# ...

# %%
img_array = np.array(img)

# %%
img_array[172, 628, :]
# Out:
# array([0, 0, 0], dtype=uint8)

# %%
img_array.max()
# Out:
# 255
