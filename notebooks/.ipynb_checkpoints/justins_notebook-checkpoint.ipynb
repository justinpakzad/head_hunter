# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
import json
import numpy as np
from PIL import Image
import os

# %%
path_train = '/Users/justinpak/code/justinpakzad/head_hunter/head_hunter/raw_data/RGBT-CC-CVPR2021/train'
path_test = '/Users/justinpak/code/justinpakzad/head_hunter/head_hunter/raw_data/RGBT-CC-CVPR2021/test'

# %%
files = os.listdir(path)
json_files_train = [file for file in files if file.endswith(".json")]
jpg_files_train = [file for file in files if file.endswith(".jpg")]

# %%
im = jpg_files_train[7]
# Out:
# '3694_RGB.jpg'

# %%
plt.imshow(picture)
plt.scatter(x=coordinates[:,0],y=coordinates[:,1],color=(1,0,0),s=5)
